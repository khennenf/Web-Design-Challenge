# %%
import pandas as pd

# %%
for_html = "Weather_Output.csv"

# %%
to_df = pd.read_csv(for_html)

# %%
to_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  Punta Arenas -53.1500  -70.9167     48.20        61           0
# 1        1        Hobart -42.8794  147.3294     77.00        53          75
# 2        2         Kālol  22.6000   73.4500     59.00        82           0
# 3        3          Asău  46.4333   26.4000     34.00        74         100
# 4        4        Faanui -16.4833 -151.7500     81.64        64           3
#
#    Wind Speed Country       Date
# 0       16.11      CL  1/30/2021
# 1       13.80      AU  1/30/2021
# 2        4.61      IN  1/30/2021
# 3        1.32      RO  1/30/2021
# 4        4.07      PF  1/30/2021

# %%
for_table = to_df.to_html("for_table_no_index.html", index=False)

# %%
to_df_html = to_df.drop("City_ID", axis=1)

# %%
to_df_html
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas -53.1500  -70.9167     48.20        61           0
# 1          Hobart -42.8794  147.3294     77.00        53          75
# 2           Kālol  22.6000   73.4500     59.00        82           0
# 3            Asău  46.4333   26.4000     34.00        74         100
# 4          Faanui -16.4833 -151.7500     81.64        64           3
# ..            ...      ...       ...       ...       ...         ...
# 808       Atambua  -9.1061  124.8925     77.20        87          98
# 809        Olinda  -8.0089  -34.8553     78.80        73          75
# 810    Nouadhibou  20.9310  -17.0347     62.60        77          40
# 811        Tsumeb -19.2333   17.7167     73.80        59          99
# 812      Waingapu  -9.6567  120.2641     82.69        73         100
#
#      Wind Speed Country       Date
# 0         16.11      CL  1/30/2021
# 1         13.80      AU  1/30/2021
# ...

# %% [raw]
# to_df_html.to_html(index=False)

# %%
for_table = to_df_html.to_html("for_table.html", index=False)
